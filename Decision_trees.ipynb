# %%
# %pip install numpy==2.2.0 pandas==2.2.3 scikit-learn==1.6.0 matplotlib==3.9.3
# Out:
# Collecting numpy==2.2.0
#   Downloading numpy-2.2.0.tar.gz (20.2 MB)
#      ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#       --------------------------------------- 0.3/20.2 MB ? eta -:--:--
#      - -------------------------------------- 0.8/20.2 MB 2.1 MB/s eta 0:00:10
#      -- ------------------------------------- 1.3/20.2 MB 2.2 MB/s eta 0:00:09
#      --- ------------------------------------ 1.6/20.2 MB 2.2 MB/s eta 0:00:09
#      ---- ----------------------------------- 2.1/20.2 MB 2.1 MB/s eta 0:00:09
#      ----- ---------------------------------- 2.6/20.2 MB 2.2 MB/s eta 0:00:09
#      ----- ---------------------------------- 2.9/20.2 MB 2.2 MB/s eta 0:00:08
#      ------ --------------------------------- 3.4/20.2 MB 2.2 MB/s eta 0:00:08
#      ------- -------------------------------- 3.9/20.2 MB 2.2 MB/s eta 0:00:08
#      -------- ------------------------------- 4.5/20.2 MB 2.2 MB/s eta 0:00:08
#      --------- ------------------------------ 4.7/20.2 MB 2.2 MB/s eta 0:00:08
#      ---------- ----------------------------- 5.2/20.2 MB 2.1 MB/s eta 0:00:07
#      ---------- ----------------------------- 5.5/20.2 MB 2.1 MB/s eta 0:00:07
#      ----------- ---------------------------- 6.0/20.2 MB 2.1 MB/s eta 0:00:07
#      ------------ --------------------------- 6.3/20.2 MB 2.1 MB/s eta 0:00:07
#      ------------- -------------------------- 6.8/20.2 MB 2.1 MB/s eta 0:00:07
#      ------------- -------------------------- 7.1/20.2 MB 2.1 MB/s eta 0:00:07
#      --------------- ------------------------ 7.6/20.2 MB 2.1 MB/s eta 0:00:07
#      --------------- ------------------------ 7.9/20.2 MB 2.1 MB/s eta 0:00:06
#      ---------------- ----------------------- 8.4/20.2 MB 2.1 MB/s eta 0:00:06
#      ----------------- ---------------------- 8.9/20.2 MB 2.1 MB/s eta 0:00:06
#      ------------------ --------------------- 9.2/20.2 MB 2.0 MB/s eta 0:00:06
#      ------------------ --------------------- 9.4/20.2 MB 2.0 MB/s eta 0:00:06
#      ------------------- -------------------- 10.0/20.2 MB 2.0 MB/s eta 0:00:06
#      -------------------- ------------------- 10.2/20.2 MB 2.0 MB/s eta 0:00:05
#      -------------------- ------------------- 10.5/20.2 MB 2.0 MB/s eta 0:00:05
#      --------------------- ------------------ 11.0/20.2 MB 2.0 MB/s eta 0:00:05
#      ---------------------- ----------------- 11.3/20.2 MB 2.0 MB/s eta 0:00:05
#      ----------------------- ---------------- 11.8/20.2 MB 2.0 MB/s eta 0:00:05
#      ----------------------- ---------------- 12.1/20.2 MB 2.0 MB/s eta 0:00:05
#      ------------------------ --------------- 12.6/20.2 MB 2.0 MB/s eta 0:00:04
#      ------------------------- -------------- 13.1/20.2 MB 2.0 MB/s eta 0:00:04
#      -------------------------- ------------- 13.4/20.2 MB 2.0 MB/s eta 0:00:04
#      --------------------------- ------------ 13.9/20.2 MB 2.0 MB/s eta 0:00:04
#      --------------------------- ------------ 14.2/20.2 MB 2.0 MB/s eta 0:00:04
#      ----------------------------- ---------- 14.7/20.2 MB 2.0 MB/s eta 0:00:03
#      ------------------------------ --------- 15.2/20.2 MB 2.0 MB/s eta 0:00:03
#      ------------------------------ --------- 15.5/20.2 MB 2.0 MB/s eta 0:00:03
#      ------------------------------- -------- 16.0/20.2 MB 2.0 MB/s eta 0:00:03
#      -------------------------------- ------- 16.3/20.2 MB 2.0 MB/s eta 0:00:02
#      --------------------------------- ------ 16.8/20.2 MB 2.0 MB/s eta 0:00:02
#      ---------------------------------- ----- 17.3/20.2 MB 2.0 MB/s eta 0:00:02
#      ---------------------------------- ----- 17.6/20.2 MB 2.0 MB/s eta 0:00:02
#      ----------------------------------- ---- 18.1/20.2 MB 2.0 MB/s eta 0:00:02
#      ------------------------------------ --- 18.6/20.2 MB 2.0 MB/s eta 0:00:01
#      ------------------------------------- -- 18.9/20.2 MB 2.0 MB/s eta 0:00:01
#      -------------------------------------- - 19.4/20.2 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  19.9/20.2 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  20.2/20.2 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------- 20.2/20.2 MB 2.0 MB/s  0:00:10
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + c:\Users\azzag\AppData\Local\Python\pythoncore-3.14-64\python.exe C:\Users\azzag\AppData\Local\Temp\pip-install-2z52flv1\numpy_4486d986d1bf4280a4607ddc9bebee6a\vendored-meson\meson\meson.py setup C:\Users\azzag\AppData\Local\Temp\pip-install-2z52flv1\numpy_4486d986d1bf4280a4607ddc9bebee6a C:\Users\azzag\AppData\Local\Temp\pip-install-2z52flv1\numpy_4486d986d1bf4280a4607ddc9bebee6a\.mesonpy-yyfhdey8 -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\azzag\AppData\Local\Temp\pip-install-2z52flv1\numpy_4486d986d1bf4280a4607ddc9bebee6a\.mesonpy-yyfhdey8\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.5.2
#       Source dir: C:\Users\azzag\AppData\Local\Temp\pip-install-2z52flv1\numpy_4486d986d1bf4280a4607ddc9bebee6a
#       Build dir: C:\Users\azzag\AppData\Local\Temp\pip-install-2z52flv1\numpy_4486d986d1bf4280a4607ddc9bebee6a\.mesonpy-yyfhdey8
#       Build type: native build
#       Project name: NumPy
#       Project version: 2.2.0
#       WARNING: Failed to activate VS environment: Could not find C:\Program Files (x86)\Microsoft Visual Studio\Installer\vswhere.exe
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] Le fichier spÃ©cifiÃ© est introuvable"
#       Running `cl /?` gave "[WinError 2] Le fichier spÃ©cifiÃ© est introuvable"
#       Running `cc --version` gave "[WinError 2] Le fichier spÃ©cifiÃ© est introuvable"
#       Running `gcc --version` gave "[WinError 2] Le fichier spÃ©cifiÃ© est introuvable"
#       Running `clang --version` gave "[WinError 2] Le fichier spÃ©cifiÃ© est introuvable"
#       Running `clang-cl /?` gave "[WinError 2] Le fichier spÃ©cifiÃ© est introuvable"
#       Running `pgcc --version` gave "[WinError 2] Le fichier spÃ©cifiÃ© est introuvable"
#
#       A full log can be found at C:\Users\azzag\AppData\Local\Temp\pip-install-2z52flv1\numpy_4486d986d1bf4280a4607ddc9bebee6a\.mesonpy-yyfhdey8\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import numpy as np 
import pandas as pd
import sys
# !{sys.executable} -m pip install matplotlib
import sys
# !{sys.executable} -m pip install scikit-learn pandas numpy matplotlib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import metrics

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: matplotlib in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\azzag\appdata\roaming\python\python314\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\azzag\appdata\roaming\python\python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\azzag\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (1.8.0)
# Requirement already satisfied: pandas in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (2.3.5)
# Requirement already satisfied: matplotlib in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (3.10.8)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\azzag\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\azzag\appdata\roaming\python\python314\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\azzag\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\azzag\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
path= 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%203/data/drug200.csv'
my_data = pd.read_csv(path)
my_data
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
my_data['Sex'] = label_encoder.fit_transform(my_data['Sex']) 
my_data['BP'] = label_encoder.fit_transform(my_data['BP'])
my_data['Cholesterol'] = label_encoder.fit_transform(my_data['Cholesterol']) 
my_data
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 0     23    0   0            0   25.355  drugY
# 1     47    1   1            0   13.093  drugC
# 2     47    1   1            0   10.114  drugC
# 3     28    0   2            0    7.798  drugX
# 4     61    0   1            0   18.043  drugY
# ..   ...  ...  ..          ...      ...    ...
# 195   56    0   1            0   11.567  drugC
# 196   16    1   1            0   12.006  drugC
# 197   52    1   2            0    9.894  drugX
# 198   23    1   2            1   14.020  drugX
# 199   40    0   1            1   11.349  drugX
#
# [200 rows x 6 columns]

# %%
my_data.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
custom_map = {'drugA':0,'drugB':1,'drugC':2,'drugX':3,'drugY':4}
my_data['Drug_num'] = my_data['Drug'].map(custom_map)
my_data
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K   Drug  Drug_num
# 0     23    0   0            0   25.355  drugY         4
# 1     47    1   1            0   13.093  drugC         2
# 2     47    1   1            0   10.114  drugC         2
# 3     28    0   2            0    7.798  drugX         3
# 4     61    0   1            0   18.043  drugY         4
# ..   ...  ...  ..          ...      ...    ...       ...
# 195   56    0   1            0   11.567  drugC         2
# 196   16    1   1            0   12.006  drugC         2
# 197   52    1   2            0    9.894  drugX         3
# 198   23    1   2            1   14.020  drugX         3
# 199   40    0   1            1   11.349  drugX         3
#
# [200 rows x 7 columns]

# %%
my_data.drop('Drug',axis=1).corr()['Drug_num']
# Out:
# Age           -0.004828
# Sex           -0.098573
# BP             0.372868
# Cholesterol    0.055629
# Na_to_K        0.589120
# Drug_num       1.000000
# Name: Drug_num, dtype: float64

# %%
# 1. On calcule les fréquences (ex: combien de 'DrugA', 'DrugB', etc.)
category_counts = my_data['Drug'].value_counts()

# 2. Maintenant on peut dessiner
import matplotlib.pyplot as plt

plt.bar(category_counts.index, category_counts.values, color='blue')
plt.xlabel('Drug')
plt.ylabel('Count')
plt.title('Distribution des Médicaments')
plt.show()

# %% [markdown]
# MODELING

# %%
y = my_data['Drug']
X = my_data.drop(['Drug','Drug_num'], axis=1)

# %%
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.3, random_state=32)

# %%
drugTree = DecisionTreeClassifier(criterion="entropy", max_depth = 4)

# %%
drugTree.fit(X_trainset,y_trainset)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %% [markdown]
# Evaluation

# %%
tree_predictions = drugTree.predict(X_testset)

# %%
print("Decision Trees's Accuracy: ", metrics.accuracy_score(y_testset, tree_predictions))
# Out:
# Decision Trees's Accuracy:  0.9833333333333333

# %% [markdown]
# ### Visualize the tree
#
# To understand the classification criteria derived by the Decision Tree, we may generate the tree plot.

# %%
plot_tree(drugTree)
plt.show()
